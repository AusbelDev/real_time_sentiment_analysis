# %%
from PIL import Image
import matplotlib.pyplot as plt
from feat import Detector, utils
import time
from rmn import RMN
# Out:
# pretrained_ckpt does not exists!
# ...
# deploy.prototxt.txt does not exists!
# ...
# res10_300x300_ssd_iter_140000.caffemodel does not exists!
# ...

# %%
# utils.set_torch_device(device="mps")
# face_model = "retinaface"
# landmark_model = "mobilenet"
# au_model = "xgb"
emotion_model = "resmasknet"
# detector = Detector(face_model=face_model, landmark_model=landmark_model, 
                    # au_model=au_model, emotion_model=emotion_model)
detector = Detector(emotion_model=emotion_model)

# %%
# test_image = "/Users/ausbel/Pictures/Picture1.jpg"
test_image = "/Users/ausbel/Pictures/69947297.jpeg"
f, ax = plt.subplots()
im = Image.open(test_image)
ax.imshow(im)

start = time.time()
image_prediction = detector.detect_image(test_image)
end = time.time()

image_prediction.plot_detections()

plt.show()

image_prediction.emotions

print(f"Time taken: {end - start} seconds")
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.29it/s]
# Time taken: 0.7802917957305908 seconds

# %%
m = RMN()
m.video_demo()
# Out:
# num faces: 0
# num faces: 0
# num faces: 0
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# num faces: 1
# ...
